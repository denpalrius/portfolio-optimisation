# %% [markdown]
# # Deep Reinforcement Learning for Portfolio Optimization - MLP Architecture

# %% [markdown]
# This experiement demonstrates the application of deep reinforcement learning (DRL) techniques for portfolio optimization.
#
# - Policy network architecture: **MLP backbone**
# - Compares `A2C`, `PPO`, `SAC`, `DDPG`, `TD3` all with simple MLPs

# %% [markdown]
# ## Dependencies

# %%
# ! pip install pandas numpy matplotlib \
#                stable-baselines3 \
#                PyPortfolioOpt \
#                pandas_market_calendars quantstats gymnasium \
#                git+https://github.com/AI4Finance-Foundation/FinRL.git -q

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import time

from tqdm.auto import tqdm

import torch

from stable_baselines3 import A2C, PPO, SAC, DDPG, TD3
from stable_baselines3.common.noise import NormalActionNoise

from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent, DRLEnsembleAgent
from finrl.plot import backtest_stats, get_daily_return, get_baseline, backtest_plot

from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
# Out:
# /Users/mzitoh/anaconda3/envs/portfolio_opt/lib/python3.12/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %matplotlib inline

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
experiment_name = "mlp_5_models_report"
results_dir = f"results/models/{experiment_name}"
os.makedirs(results_dir, exist_ok=True)

# %% [markdown]
# ## Data loading and pre-processing

# %% [markdown]
# Define training and trading/test periods

# %%
start_date = "2015-01-01"
end_date = (datetime.now() - pd.Timedelta(days=1)).strftime("%Y-%m-%d")  # Yesterday

trade_period = 2  # 2 years for testing
train_period = 10  # 10 years for training

train_end_date = (
    datetime.strptime(end_date, "%Y-%m-%d") - timedelta(days=trade_period * 365)
).strftime("%Y-%m-%d")
train_start_date = (
    datetime.strptime(train_end_date, "%Y-%m-%d") - timedelta(days=train_period * 365)
).strftime("%Y-%m-%d")
test_start_date = (
    datetime.strptime(train_end_date, "%Y-%m-%d") + timedelta(days=1)
).strftime("%Y-%m-%d")

train_dates = (train_start_date, train_end_date)
test_dates = (test_start_date, end_date)

print(f"Training period: {train_dates}")
print(f"Testing period: {test_dates}")
# Out:
# Training period: ('2013-05-06', '2023-05-04')
# Testing period: ('2023-05-05', '2025-05-03')

# %% [markdown]
# - Fetch historical stock data for a given list of tickers within a specified date range.
# - We use the DOW_30_TICKER stocks
# - The data includes `date`, `close`, `high`, `low`, `open`, `volume`, and `tic` (ticker symbol).

# %%
def download_data(tickers, start_date, end_date):
    print(f"Downloading {start_date} → {end_date}")
    return YahooDownloader(
        start_date=start_date, end_date=end_date, ticker_list=tickers
    ).fetch_data()


df = download_data(config_tickers.DOW_30_TICKER, start_date, end_date)
# Out:
# Downloading 2015-01-01 → 2025-05-03
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (76911, 8)

# %% [markdown]
# ---
#
# We apply feature engineering to the dataset of stock data:
#
# - Add technical indicators (e.g., moving averages, RSI).
# - Calculate turbulence indicators, which measure market volatility.
#
# This Enhance the dataset with features that are critical for modeling market dynamics and making informed trading decisions.

# %%
def preprocess_data(df):
    fe = FeatureEngineer(use_technical_indicator=True, use_turbulence=True)
    return fe.preprocess_data(df)


df_feat = preprocess_data(df)

# TODO: Normalise the data??
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %% [markdown]
# ## Covariance & Returns for State

# %% [markdown]
# - Calculate the rolling covariance matrices and daily returns for the given dataset of stock prices.
# - This prepares the state representation (the state of the portfolio) for the RL models in the RL environments for portfolio optimization.
# - The **rolling covariance matrices** (`cov_list`) capture the relationships between asset returns, while the daily returns (`return_list`) provide information about recent price movements.
# - These metrics are critical for modeling the dynamics of the financial market and making informed trading decisions.

# %%
def compute_covariance_and_returns(df_feat, lookback=252):
    df_sorted = df_feat.sort_values(["date", "tic"], ignore_index=True)
    df_sorted.index = df_sorted.date.factorize()[0]
    cov_list, return_list = [], []

    dates = df_sorted.date.unique()
    for i in tqdm(range(lookback, len(dates)), desc="Computing covariance and returns"):
        win = df_sorted.loc[i - lookback : i]
        pm = win.pivot_table(index="date", columns="tic", values="close")
        rm = pm.pct_change().dropna()
        cov_list.append(rm.cov().values)
        return_list.append(rm)
    df_cov = pd.DataFrame(
        {"date": dates[lookback:], "cov_list": cov_list, "return_list": return_list}
    )

    return pd.merge(df_feat, df_cov, on="date", how="left").dropna(subset=["cov_list"])


df_all = compute_covariance_and_returns(df_feat)
# Out:
# Computing covariance and returns:   0%|          | 0/2347 [00:00<?, ?it/s]

# %% [markdown]
# ## Train/Trade split

# %%
def split_data(df_all, train_dates, test_dates):
    train = data_split(df_all, *train_dates)
    test = data_split(df_all, *test_dates)
    return train, test


train, test = split_data(df_all, train_dates, test_dates)

# %% [markdown]
# ## Environment setup

# %% [markdown]
# - Create instances of the StockPortfolioEnv class for both training and testing datasets.
# - It also wrap the training environment for use with Stable-Baselines3 (SB3).

# %%
def configure_environment(train, test, fe):
    stock_dim = len(train.tic.unique())
    env_kwargs = dict(
        stock_dim=stock_dim,  # Number of unique stocks
        hmax=100,  # Maximum number of shares that can be traded
        initial_amount=1e6,  # Initial portfolio value (e.g., $1,000,000)
        transaction_cost_pct=0.001,  # Transaction cost as a percentage (e.g., 0.1%)
        reward_scaling=1e-4,  # Scaling factor for rewards
        state_space=stock_dim,  # State space dimension (equal to stock_dim)
        action_space=stock_dim,  # Action space dimension (equal to stock_dim)
        tech_indicator_list=fe.tech_indicator_list,  # List of technical indicators
    )

    # create the two StockPortfolioEnv objects
    raw_train_env = StockPortfolioEnv(df=train, **env_kwargs)
    raw_test_env = StockPortfolioEnv(df=test, **env_kwargs)

    # Wrap the *training* env for SB3
    env_train_sb3, _ = raw_train_env.get_sb_env()

    return env_train_sb3, raw_train_env, raw_test_env, env_kwargs


env_train_sb3, raw_train_env, raw_test_env, env_kwargs = configure_environment(
    train, test, FeatureEngineer()
)

# %% [markdown]
# ## Training

# %% [markdown]
# - We define the configuration for various RL models to be trained in the portfolio optimization environment.
# - The training environment (`env_train_sb3`) is wrapped for use with Stable-Baselines3 (SB3).
# - The SB3 environment provides the `state` and `action space` dimensions needed for configuring the models.

# %%
def prepare_models():
    model_configs = [
        (A2C, "A2C", {}),
        (PPO, "PPO", {}),
        (SAC, "SAC", {}),
        (DDPG, "DDPG", {}),
        (TD3, "TD3", {}),
    ]
    return model_configs


model_configs = prepare_models()

# %% [markdown]
# Train multiple reinforcement learning (RL) models using the specified training environment and configuration.

# %%
def train_models(env_train_sb3, model_configs, save_dir, timesteps_override=None):
    # Recommended timesteps
    timesteps_map = {
        "A2C": 150_000,  # on-policy, fewer passes
        "PPO": 250_000,  # on-policy, more stable
        "SAC": 1_000_000,  # off-policy, reuse via replay
        "DDPG": 1_000_000,  # off-policy
        "TD3": 1_000_000,  # off-policy with twin critics
    }

    models, training_times = {}, {}
    
    for cls, name, kwargs in tqdm(model_configs, desc="Training"):
        n_steps = (
            timesteps_override
            if timesteps_override is not None
            else timesteps_map[name]
        )
        print(f"Training {name} for {n_steps} timesteps…")
        start_time = time.time()

        model = cls("MlpPolicy", env_train_sb3, verbose=0, **kwargs)
        model.learn(total_timesteps=n_steps)

        end_time = time.time()
        training_times[name] = (end_time - start_time) / 60
        models[name] = model
        model.save(f"{save_dir}/{name}_mlp_model")

        print(f"{name} training completed in {training_times[name]:.2f} minutes.")

    return models, training_times

# %%
models, training_times = train_models(env_train_sb3, model_configs, results_dir, timesteps_override=1_000_000)
# Out:
# Training A2C for 1000000 timesteps…
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2536355.0551805715
# Sharpe:  0.7731357376952585
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2418232.993605473
# Sharpe:  0.7401954294650349
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2715306.2929689977
# Sharpe:  0.8231183004378322
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2429701.4425720046
# Sharpe:  0.7437975977877509
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2568760.7343771243
# Sharpe:  0.7870791064196323
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2553501.3877221886
# Sharpe:  0.7854034506727943
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2460311.5861158976
# Sharpe:  0.7680577297275304
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2375934.4306676225
# Sharpe:  0.7368457640434622
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2417986.00162352
# Sharpe:  0.7467477896973752
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2322938.947809012
# Sharpe:  0.7199740436045232
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2338114.3949870146
# Sharpe:  0.7216411749714515
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2406812.2709968425
# Sharpe:  0.7410753890000551
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2341954.082543192
# Sharpe:  0.7263429231248496
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2485363.1855406906
# Sharpe:  0.7717156875744476
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2322431.2358323727
# Sharpe:  0.7153505084870765
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2454469.330787358
# Sharpe:  0.7583797412525867
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2494033.6939737163
# Sharpe:  0.7776868194071771
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2351743.0643386743
# Sharpe:  0.7310929993031222
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2490837.744021207
# Sharpe:  0.7709708554715394
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2411834.4100340963
# Sharpe:  0.7469462692621199
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2363275.7010129387
# Sharpe:  0.7340639874418263
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2433890.4606262515
# Sharpe:  0.754306840877208
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2350414.700293798
# Sharpe:  0.7275715771840126
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2386177.871571085
# Sharpe:  0.7366030442370873
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2469798.020010676
# Sharpe:  0.7632300970068633
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2310471.151801633
# Sharpe:  0.7166566735542058
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2458151.123495
# Sharpe:  0.7667067691858758
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2434667.9664021484
# Sharpe:  0.7519390755249346
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2507123.3892962974
# Sharpe:  0.7754599590640924
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2436561.6691114083
# Sharpe:  0.7525613126533128
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2416190.3114541904
# Sharpe:  0.7460291462334226
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2507373.4820550294
# Sharpe:  0.7756952070487989
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2417397.7306892024
# Sharpe:  0.7474759068112105
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2386278.759854152
# Sharpe:  0.7339977818241116
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2432464.8560492187
# Sharpe:  0.7481521100079005
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2563726.5720269713
# Sharpe:  0.7903372171319282
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2374971.1744871563
# Sharpe:  0.7288102725103943
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2491315.829429637
# Sharpe:  0.7657267488327579
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2485979.526076563
# Sharpe:  0.7621160599540615
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2461918.4993850705
# Sharpe:  0.7534382759843159
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2605412.214624686
# Sharpe:  0.7980857843559556
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2536681.1966767926
# Sharpe:  0.7761146034019596
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2470999.5182294967
# Sharpe:  0.7564753965535638
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2654328.553592037
# Sharpe:  0.8107524259221239
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2555914.1670081997
# Sharpe:  0.7878160829987673
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2522322.7999008233
# Sharpe:  0.7739883670417648
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2581590.948212475
# Sharpe:  0.7849735235277151
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2548690.403650636
# Sharpe:  0.7790031924150626
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2562416.708041005
# Sharpe:  0.7774589705870757
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2581669.9878266635
# Sharpe:  0.7847198717903108
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2565141.9792220094
# Sharpe:  0.7794752153091288
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2575052.7096808855
# Sharpe:  0.7789471518155461
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2616552.9153593904
# Sharpe:  0.7900944661774123
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2625921.203592818
# Sharpe:  0.791912958508597
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2580408.476965696
# Sharpe:  0.7759468089441383
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2688249.989743152
# Sharpe:  0.8130617791739952
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2582714.172604596
# Sharpe:  0.7803025330386936
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2618444.0085486006
# Sharpe:  0.7880794043460909
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2619441.4225962516
# Sharpe:  0.7838279643709333
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2667815.6758143846
# Sharpe:  0.8010917241986055
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2655937.22671158
# Sharpe:  0.798977987769528
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2599260.376178153
# Sharpe:  0.7801232888132609
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2623694.4828384966
# Sharpe:  0.7892361243102488
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2566387.1705425377
# Sharpe:  0.7677332124126858
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2544469.7049419372
# Sharpe:  0.7550937909473764
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2566582.081029289
# Sharpe:  0.7610223965048024
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2600575.6321395994
# Sharpe:  0.7700702622976111
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2510661.3914459427
# Sharpe:  0.7453450082406522
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2649265.880833113
# Sharpe:  0.7836813577591824
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2606982.4327516267
# Sharpe:  0.773361758808172
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2535206.482794197
# Sharpe:  0.7523937460344003
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2503374.3362251474
# Sharpe:  0.7440332091421775
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2537388.4787965054
# Sharpe:  0.7538370303822769
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2576688.646396265
# Sharpe:  0.7654649264168254
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2520929.3636888135
# Sharpe:  0.7490692423481496
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2520263.5646317997
# Sharpe:  0.7491936390973496
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2523675.170135712
# Sharpe:  0.7476241500159226
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2567428.2860693103
# Sharpe:  0.7604747816243532
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2565312.856971986
# Sharpe:  0.7692317152401661
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2573475.1026780326
# Sharpe:  0.7732365541075034
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2515251.9921471216
# Sharpe:  0.754445790880086
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2507155.720081873
# Sharpe:  0.7623169692879924
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2564429.8540302394
# Sharpe:  0.7794350168038754
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2601515.995078005
# Sharpe:  0.8011013626094237
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2567731.9438927467
# Sharpe:  0.793511372325482
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2562310.6410895907
# Sharpe:  0.7976177312151839
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2600435.6221962227
# Sharpe:  0.8095218991441699
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2485444.6966369557
# Sharpe:  0.7766670354740618
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2495307.5354293943
# Sharpe:  0.774532303143688
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2580626.9498953493
# Sharpe:  0.8040183545205417
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2554880.592241409
# Sharpe:  0.8005049006959082
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2524028.058417544
# Sharpe:  0.7920652071828433
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2544870.9523188854
# Sharpe:  0.8017670085425209
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2556735.4522517957
# Sharpe:  0.7990260198838655
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2602032.274840415
# Sharpe:  0.810438859360294
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2569577.9299748396
# Sharpe:  0.8034214953965699
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2567102.3757795594
# Sharpe:  0.802864204759114
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2624799.22846239
# Sharpe:  0.817475017475056
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2627956.465989523
# Sharpe:  0.8171824844158533
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2594502.9713907433
# Sharpe:  0.809178583098973
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2630024.588991694
# Sharpe:  0.8187492847306381
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2634646.03612219
# Sharpe:  0.8177399680014811
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2563330.54213603
# Sharpe:  0.7971315572832328
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2594347.726879649
# Sharpe:  0.8083531389975195
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2579388.1968750944
# Sharpe:  0.8043510801856788
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2625265.7209279938
# Sharpe:  0.8152749644045519
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2593554.768448569
# Sharpe:  0.7915366748034611
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2479399.2769176033
# Sharpe:  0.7527295357553863
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2562271.9531561006
# Sharpe:  0.7772822224590459
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2519103.4899391886
# Sharpe:  0.7626054289608156
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2463486.687048864
# Sharpe:  0.7426686522052204
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2492843.32695669
# Sharpe:  0.7566154288888596
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2524078.3170121596
# Sharpe:  0.7653285642890117
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2512671.4231555187
# Sharpe:  0.7611420717268338
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2515508.6477065375
# Sharpe:  0.7607360195319436
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2541268.6571246968
# Sharpe:  0.7724169575758221
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2624745.195436218
# Sharpe:  0.7929502956269646
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2533386.0682716123
# Sharpe:  0.7694254754689169
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2605228.5223731603
# Sharpe:  0.7939261843904457
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2575733.153699332
# Sharpe:  0.7820059127651561
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2494050.6115497784
# Sharpe:  0.7580451369155004
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2513688.0391528956
# Sharpe:  0.7640372908302268
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2545799.373644148
# Sharpe:  0.769788631306823
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2482202.1656778986
# Sharpe:  0.7590326934761116
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2488680.490557779
# Sharpe:  0.7633745005013325
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2563259.3105979897
# Sharpe:  0.7844260324651555
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2580975.3944287603
# Sharpe:  0.7834050722874908
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2520792.416602348
# Sharpe:  0.765453619251555
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2495079.6634691413
# Sharpe:  0.7575376881075369
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2488402.9583603074
# Sharpe:  0.7558895723685605
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2499298.0913783317
# Sharpe:  0.7594217614746162
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2447818.724196421
# Sharpe:  0.7376090262402083
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2477951.8858706453
# Sharpe:  0.7510480770348705
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2542092.7122878744
# Sharpe:  0.7678485761446633
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2490336.995449513
# Sharpe:  0.7526697214342836
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2495102.2382305716
# Sharpe:  0.75840187999221
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2534658.0090241535
# Sharpe:  0.7710531323223636
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2653285.61452181
# Sharpe:  0.8039428019920893
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2631560.90518234
# Sharpe:  0.7990823293379585
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2643187.430490644
# Sharpe:  0.8009379365317418
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2652298.10306765
# Sharpe:  0.8043915329118044
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2663260.6614744407
# Sharpe:  0.8074574979055987
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2645190.4119600826
# Sharpe:  0.8011418471973424
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2649612.2118999274
# Sharpe:  0.802449051233686
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2633321.917306229
# Sharpe:  0.8000978788341816
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2663178.3372312915
# Sharpe:  0.8115346356380627
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2657469.7194810333
# Sharpe:  0.8063416827294891
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2691994.587048871
# Sharpe:  0.8209509205983306
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2688405.1106701205
# Sharpe:  0.8169582109779906
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2635126.0148096294
# Sharpe:  0.8068999325394335
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2666983.650479683
# Sharpe:  0.8128252187811295
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2677679.1868932974
# Sharpe:  0.8136898302448928
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2670978.2908834587
# Sharpe:  0.8121898699977906
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2636701.1702781976
# Sharpe:  0.8025551527998357
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2645667.1316638393
# Sharpe:  0.8045837018791454
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2616485.142945937
# Sharpe:  0.7973494929969175
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2576033.8706516735
# Sharpe:  0.7832594281727248
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2520864.672184058
# Sharpe:  0.7659802184665994
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2507551.666791176
# Sharpe:  0.7631779058594517
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2479476.854597937
# Sharpe:  0.7559115598603966
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2501112.776017161
# Sharpe:  0.7629609755631586
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2517866.9524931572
# Sharpe:  0.7657643266847151
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2515108.8107587574
# Sharpe:  0.7669790051061441
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2548563.5248295134
# Sharpe:  0.7744903977642189
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2583480.8350899294
# Sharpe:  0.7838548135728892
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2598046.5063498267
# Sharpe:  0.7876932094393098
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2599527.1117397244
# Sharpe:  0.7881222363651489
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2604665.8102128594
# Sharpe:  0.7933056839974365
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2598955.6306910426
# Sharpe:  0.7898910291002997
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2602282.6838693228
# Sharpe:  0.7906046277194404
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2585432.150931677
# Sharpe:  0.7887956072524609
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2563215.3989429045
# Sharpe:  0.7805835641693641
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2577677.102284103
# Sharpe:  0.7835042881549958
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2583873.5590095255
# Sharpe:  0.7867700683505189
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2576182.2783492976
# Sharpe:  0.7846888693218222
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2576703.371936655
# Sharpe:  0.7835363975346783
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2598188.2941939086
# Sharpe:  0.787869792985686
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2594824.479189798
# Sharpe:  0.7885328688620129
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2607134.2890901454
# Sharpe:  0.7921241317573647
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2651401.8046609233
# Sharpe:  0.8044183013210585
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2685354.5624851095
# Sharpe:  0.8133082428180923
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2676792.688559644
# Sharpe:  0.8141819772913315
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2707792.174210436
# Sharpe:  0.8248397671422942
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2701907.2216834794
# Sharpe:  0.8224393528169555
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2657613.649961538
# Sharpe:  0.8112816070498338
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2717779.0453319633
# Sharpe:  0.8270779289031931
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2652394.746337367
# Sharpe:  0.80970371379619
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2637078.497078301
# Sharpe:  0.8053521008317758
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2699361.362900186
# Sharpe:  0.8214509377878657
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2679873.6668167813
# Sharpe:  0.8163884566674195
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2679262.1524864775
# Sharpe:  0.8171183810695858
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2649696.3563959617
# Sharpe:  0.8082208239140989
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2678034.1928245453
# Sharpe:  0.8109243216009049
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2724546.21191847
# Sharpe:  0.8255320653011183
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2737741.4682763764
# Sharpe:  0.8342392476840124
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2755680.0678846505
# Sharpe:  0.8388546893309581
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2697941.1081775664
# Sharpe:  0.8252688483709382
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2679895.2805797355
# Sharpe:  0.8187981373916641
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2677953.806722301
# Sharpe:  0.8133349618327242
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2722865.6258595404
# Sharpe:  0.8272600556438817
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2702512.9118619864
# Sharpe:  0.8271066387978606
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2735836.5289534647
# Sharpe:  0.836256138280733
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2729993.1195014063
# Sharpe:  0.8343417874954437
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2754539.3571172203
# Sharpe:  0.8372814461881483
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2740438.6386208595
# Sharpe:  0.8403041949252715
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2755965.017401433
# Sharpe:  0.8467369942877797
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2721150.9134384827
# Sharpe:  0.836671365393295
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2736940.953617624
# Sharpe:  0.8397541190579899
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2734263.7911321637
# Sharpe:  0.8357542042877516
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2745344.4725862048
# Sharpe:  0.8320174185606405
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2717008.9441118115
# Sharpe:  0.8254136346828976
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2756928.70417414
# Sharpe:  0.837628955564316
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2753355.9794174894
# Sharpe:  0.8386809637539265
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2773629.5269301045
# Sharpe:  0.8423573005287552
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2735838.178224424
# Sharpe:  0.8331676467551179
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2638371.1189139327
# Sharpe:  0.8064420643603651
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2659045.541884439
# Sharpe:  0.81001504924061
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2647438.564188229
# Sharpe:  0.807900608762062
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2704650.900921692
# Sharpe:  0.8208183243911281
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2640294.3478735276
# Sharpe:  0.8044605443104482
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2642834.148325272
# Sharpe:  0.8052373116733063
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2641825.5539901312
# Sharpe:  0.8052556928136819
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2670429.772018969
# Sharpe:  0.8152825524014655
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2687101.5569800967
# Sharpe:  0.8177521360340926
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2716711.3155253665
# Sharpe:  0.8240877446668182
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2720375.8106451984
# Sharpe:  0.8262088119448261
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2690166.8761924123
# Sharpe:  0.8140336229351464
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2740346.458881543
# Sharpe:  0.825657289976393
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2719259.783786224
# Sharpe:  0.8198219494945277
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2716736.4912822647
# Sharpe:  0.8174627976843244
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2644801.0610839403
# Sharpe:  0.7966406139239616
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2730572.6974942335
# Sharpe:  0.815609823686928
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2769761.338643309
# Sharpe:  0.8317031400189233
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2733207.3353330707
# Sharpe:  0.823013774121236
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2735651.15913977
# Sharpe:  0.8245114251550526
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2714898.867547125
# Sharpe:  0.8183400074420973
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2744083.4447408156
# Sharpe:  0.825125758028628
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2710684.485847068
# Sharpe:  0.8133720174396988
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2765111.5990200033
# Sharpe:  0.8303479764571295
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2745510.443015172
# Sharpe:  0.8262672082019494
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2745459.719163185
# Sharpe:  0.820686031018541
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2718305.8441351973
# Sharpe:  0.815153875255773
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2714462.1101205642
# Sharpe:  0.8147974425702155
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2691146.028717147
# Sharpe:  0.8110051138875981
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2726241.313672111
# Sharpe:  0.8245792565593455
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2750546.7716910467
# Sharpe:  0.8292708171039782
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2717054.775461185
# Sharpe:  0.8249757043851236
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2726933.797451596
# Sharpe:  0.8290192967926726
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2728746.0972214015
# Sharpe:  0.8307548352437446
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2814761.473774864
# Sharpe:  0.8506018021571122
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2740317.08227424
# Sharpe:  0.8208202891242924
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2749926.1314583295
# Sharpe:  0.8234632541565983
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2735590.8040008936
# Sharpe:  0.8185014245232194
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2706551.5205223993
# Sharpe:  0.8121458202551182
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2740278.1823404045
# Sharpe:  0.8188098530414929
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2722942.6501363292
# Sharpe:  0.8162846998096129
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2695108.2508475236
# Sharpe:  0.8051022902668604
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2726795.382392165
# Sharpe:  0.8122647239813512
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2722685.7243702463
# Sharpe:  0.8088928029519384
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2720461.639548849
# Sharpe:  0.8122803402053405
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2720139.984857075
# Sharpe:  0.8127151921505801
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2743319.6640221174
# Sharpe:  0.8196958196376918
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2713618.575861768
# Sharpe:  0.8108399510390175
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2700355.3235506136
# Sharpe:  0.8078465205201084
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2722476.7503199233
# Sharpe:  0.8129116476974689
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2731666.425725901
# Sharpe:  0.8199574753249294
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2734267.2183648883
# Sharpe:  0.8184664262666943
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2729192.9430447416
# Sharpe:  0.8145557023666035
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2712116.0306659816
# Sharpe:  0.8111513879606546
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2755289.6267617075
# Sharpe:  0.8224409103030371
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2734939.0714186397
# Sharpe:  0.8169686858297247
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2759480.37955564
# Sharpe:  0.8248232283125235
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2671518.6304928213
# Sharpe:  0.7996962127166706
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2726700.85485834
# Sharpe:  0.8127377134172191
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2752268.5671770456
# Sharpe:  0.819227611644099
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2734465.46105783
# Sharpe:  0.814823380122727
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2697081.4854696174
# Sharpe:  0.8035876590252583
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2684798.1909636715
# Sharpe:  0.8014414176761496
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2673569.509981282
# Sharpe:  0.799113243688678
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2693815.19803049
# Sharpe:  0.8111535649439268
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2667285.179449645
# Sharpe:  0.8038670797877525
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2626727.525445538
# Sharpe:  0.789948758872043
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2558191.582335751
# Sharpe:  0.7774040479295173
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2599923.048652732
# Sharpe:  0.7876908324082789
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2565203.456601336
# Sharpe:  0.7698488670846394
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2558844.19046888
# Sharpe:  0.774291000152044
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2620465.625259516
# Sharpe:  0.7930909058208951
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2581918.797248591
# Sharpe:  0.78117228388218
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2522070.108776392
# Sharpe:  0.7650504906775842
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2538182.770026346
# Sharpe:  0.7664019818216834
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2526703.522090461
# Sharpe:  0.7662700608947497
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2548098.4925621874
# Sharpe:  0.7697690885538804
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2605699.5350188706
# Sharpe:  0.7789218859235019
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2560266.3691428117
# Sharpe:  0.7700392440468669
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2554438.475046169
# Sharpe:  0.7677162996069977
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2557389.730619673
# Sharpe:  0.7682616383221524
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2565952.4481865135
# Sharpe:  0.770243962404978
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2577823.607306323
# Sharpe:  0.7734305904347604
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2583320.923655043
# Sharpe:  0.7743302466643773
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2549656.1861900724
# Sharpe:  0.7637754477951237
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2575446.439294037
# Sharpe:  0.7742820293803767
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2607602.9036519406
# Sharpe:  0.782911396380675
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2578176.086451109
# Sharpe:  0.7721703322194642
# ...
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2581446.4139528237
# Sharpe:  0.7742674707832863
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2576095.522122937
# Sharpe:  0.7725395299383876
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2575565.2897927947
# Sharpe:  0.7723906494122054
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2575635.87787589
# Sharpe:  0.7724225488243484
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2574855.2488878635
# Sharpe:  0.7722737111365574
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2575089.6903402414
# Sharpe:  0.772334628049808
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2576709.6438934235
# Sharpe:  0.7728221558146899
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2575839.2956203735
# Sharpe:  0.7727154455601555
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2577486.841670648
# Sharpe:  0.7733564885635618
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2568629.7472544503
# Sharpe:  0.7710204485357237
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2569968.5405376907
# Sharpe:  0.7716161357156485
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2578563.273065185
# Sharpe:  0.7747787779803768
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2601177.0586245866
# Sharpe:  0.7813152363374728
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2592529.923335186
# Sharpe:  0.7801917532200177
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2588979.5723959617
# Sharpe:  0.7782977366673309
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2569868.2021149215
# Sharpe:  0.7745890689465886
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2579930.9068392445
# Sharpe:  0.776019436888108
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2567304.938840122
# Sharpe:  0.7717444234993691
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2615300.0844939235
# Sharpe:  0.7854528197891696
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2561185.197765896
# Sharpe:  0.7715445093137328
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2584648.133205063
# Sharpe:  0.7782476040456267
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2579496.306123098
# Sharpe:  0.7756249962867642
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2583517.0030790325
# Sharpe:  0.7771846799643835
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2547841.269907732
# Sharpe:  0.7670951110123555
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2570750.977766289
# Sharpe:  0.7752563810963994
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2610980.058626603
# Sharpe:  0.7856961640462305
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2568313.6173876924
# Sharpe:  0.7723048143673716
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2548890.082812463
# Sharpe:  0.7681232597914485
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2533784.0010751635
# Sharpe:  0.7640101638668133
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2607768.7304136376
# Sharpe:  0.7853541111065925
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2523560.1220100606
# Sharpe:  0.7604221294852466
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2571606.0764981085
# Sharpe:  0.7749613489639047
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2597250.0606570495
# Sharpe:  0.7814563854152365
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2563947.3647111016
# Sharpe:  0.7725458461298363
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2543038.536561721
# Sharpe:  0.767152183622493
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2576114.2132102367
# Sharpe:  0.7745677601727544
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2562031.3881957284
# Sharpe:  0.7728438783051083
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2546003.625673374
# Sharpe:  0.7681297311434885
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2516341.8904478345
# Sharpe:  0.7592832294238646
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2598706.0117056314
# Sharpe:  0.7828290728078904
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2586716.5455980813
# Sharpe:  0.7795434178549214
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2565541.941554347
# Sharpe:  0.775589749032516
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2513330.8790707514
# Sharpe:  0.759592073359204
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2552846.6064113853
# Sharpe:  0.7707436100248408
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2625423.555888333
# Sharpe:  0.7898748663969367
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2600806.999765105
# Sharpe:  0.7840655936637967
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2554087.991529603
# Sharpe:  0.7713331857204857
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2574274.6302774977
# Sharpe:  0.7771650319905471
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2592274.0443637962
# Sharpe:  0.7820336791647743
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2578030.9155849735
# Sharpe:  0.7783748375516218
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2531497.621464253
# Sharpe:  0.7645175808499837
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2584568.9648818723
# Sharpe:  0.7799591370469907
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2542966.8041190263
# Sharpe:  0.7683063841633545
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2564295.0362767302
# Sharpe:  0.7749156959686769
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2567853.544462197
# Sharpe:  0.7741704211198521
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2541633.875561242
# Sharpe:  0.7678705390699228
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2617335.940706768
# Sharpe:  0.7881124270230181
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2533653.0557188825
# Sharpe:  0.7659421232889296
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2538263.045418369
# Sharpe:  0.7658853486843239
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2547898.287572632
# Sharpe:  0.7692114744128532
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2521532.153460008
# Sharpe:  0.7602877111370184
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2549678.6190891424
# Sharpe:  0.7712819945638325
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2585810.541580804
# Sharpe:  0.7805995753711085
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2636306.952411816
# Sharpe:  0.7942421386464291
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2523063.0173872313
# Sharpe:  0.7637363353027068
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2535761.9243118754
# Sharpe:  0.7689132932165886
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2549313.0421253783
# Sharpe:  0.7726752370558511
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2569676.1931355386
# Sharpe:  0.7775759218088474
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2551635.4288065243
# Sharpe:  0.7733306619856882
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2517030.4065215755
# Sharpe:  0.7620583686677819
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2543045.854207635
# Sharpe:  0.7687036896522979
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2524993.97091766
# Sharpe:  0.7644209955903033
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2643981.866929429
# Sharpe:  0.7974050075773553
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2554459.940437757
# Sharpe:  0.7736580185735251
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2474739.8229456074
# Sharpe:  0.7513836163599058
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2588133.9131500125
# Sharpe:  0.7827711180326251
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2544890.12637132
# Sharpe:  0.7719442716701947
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2560119.828727215
# Sharpe:  0.774720703918528
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2533738.184966638
# Sharpe:  0.7713247830986844
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2471227.7843810613
# Sharpe:  0.7553596508729978
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2508335.225075898
# Sharpe:  0.7672013352808741
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2511159.174106592
# Sharpe:  0.7683219053531721
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2469940.5651884354
# Sharpe:  0.7586849977688166
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2446014.4187570172
# Sharpe:  0.7539112800385426
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2569578.821776041
# Sharpe:  0.7937834295290652
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2485967.595503989
# Sharpe:  0.7682275098717037
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2496371.797977059
# Sharpe:  0.7715019383020306
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2532894.424522713
# Sharpe:  0.7860341102425612
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2591554.012323089
# Sharpe:  0.8030698467144871
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2515451.0128710885
# Sharpe:  0.7833581096494788
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2579037.7707664752
# Sharpe:  0.8010590640746366
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2468135.998785962
# Sharpe:  0.7655681114494057
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2520012.7018044847
# Sharpe:  0.7783070888042647
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2484733.4179021697
# Sharpe:  0.7680681328181046
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2652622.5885670725
# Sharpe:  0.8158835540210201
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2609179.5486297454
# Sharpe:  0.800672343469851
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2539128.268737262
# Sharpe:  0.7833018994467886
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2581058.801631831
# Sharpe:  0.7901692034999621
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2635056.865866393
# Sharpe:  0.8031883527994591
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2600839.6310806675
# Sharpe:  0.795600527723323
# =================================
# =================================
# begin_total_asset:1000000.0
# end_total_asset:2615556.38592047
# Sharpe:  0.8043818312457831
# =================================

# %%
training_times_df = pd.DataFrame(
    list(training_times.items()), columns=["model", "training_duration (min)"]
)

training_times_df.to_csv(f"{results_dir}/training_times.csv", index=False)

print("Training summary:")
display(training_times_df)

# %% [markdown]
# ## Model loading

# %% [markdown]
# Load the trained models from memory for analysis without the need for time consuming retraining

# %%
def load_models(model_configs, results_dir):
    models = {}
    for _, name, _ in model_configs:
        model_path = f"{results_dir}/{name}_mlp_model.zip"
        if os.path.exists(model_path):
            print(f"Loading saved model for {name}...")
            models[name] = globals()[name].load(model_path)
        else:
            print(f"No saved model found for {name}.")
    return models


# models = load_models(model_configs, results_dir)

# %% [markdown]
# ## Backtesting

# %% [markdown]
# - Evaluates the performance of the RL models/algorithms in a trading environment.
# - We do this by calculating the **cumulative portfolio value** and **performance metrics** for each RL model.

# %%
def backtest_rl_strategies(models, raw_env, env_kwargs):
    results = {}
    for name, model in models.items():
        print(f"Backtesting {name}…")
        # Simulate trading using the model in the raw_env environment
        df_ret, _ = DRLAgent.DRL_prediction(
            model=model, environment=raw_env, deterministic=True
        )
        df_ret["account_value"] = (df_ret.daily_return + 1).cumprod() * env_kwargs[
            "initial_amount"
        ]
        stats = backtest_stats(df_ret, value_col_name="account_value")
        results[name] = {"df": df_ret, "stats": stats}
    return results


results = backtest_rl_strategies(models, raw_test_env, env_kwargs)

# %% [markdown]
# ### Plotting

# %%
def plot_backtest_results():
    for name, res in results.items():
        print(f"Plotting {name}…")
        backtest_plot(
            account_value=res["df"],
            baseline_start=test_start_date,
            baseline_end=end_date,
            baseline_ticker="SPY",
            value_col_name="account_value",
        )


plot_backtest_results()

# %% [markdown]
# ## Benchmarks

# %% [markdown]
# These benchmarks will provide baseline performance metrics for comparison with the RL strategies.
# We evaluate the performance of **Mean-Variance Optimization (MVO)** and simple benchmarks (**Equal-Weighted Portfolio** and **SPY**) in terms of returns, volatility, and cumulative portfolio value.

# %% [markdown]
# ---
#
# ### Mean-Variance Optimization Benchmark
#
# - **Objective**: Calculate the benchmark portfolio using **Mean-Variance Optimization (MVO)**.
# - **Purpose**: This function benchmarks the performance of a portfolio optimized for minimum volatility using **Modern Portfolio Theory (MPT)**.
# - **Comparison**: It allows us to compare the MPT strategy with other RL strategies by analyzing metrics like returns, volatility, and cumulative performance.
#
# ##### Workflow:
#
# 1. **Covariance Matrix**:
#
#    - Extract the covariance matrix of asset returns for each trading day in the test period.
#    - Use this matrix to model the relationships between asset returns.
#
# 2. **Optimization**:
#
#    - Apply **Efficient Frontier** to minimize portfolio volatility.
#    - Compute the optimal weights for each asset in the portfolio.
#
# 3. **Portfolio Value Calculation**:
#
#    - Calculate the portfolio's account value over time using the optimized weights and asset prices.
#
# 4. **Performance Metrics**:
#    - Evaluate the portfolio's performance using metrics such as annual return, cumulative return, and volatility.
#    - Add the results to the `results` dictionary under the `"MPT"` key.

# %%
def compute_mpt_benchmark(test, env_kwargs):
    dates_test = test.date.unique()
    min_vals = [env_kwargs["initial_amount"]]
    for i in range(len(dates_test) - 1):
        curr = test[test.date == dates_test[i]]
        nxt = test[test.date == dates_test[i + 1]]
        covm = np.array(curr.cov_list.values[0])
        ef = EfficientFrontier(None, covm, weight_bounds=(0, 1))
        ef.min_volatility()
        w = ef.clean_weights()
        prices = curr.close.values
        nextp = nxt.close.values
        shares = np.array(list(w.values())) * min_vals[-1] / prices
        min_vals.append(np.dot(shares, nextp))
    min_df = pd.DataFrame({"date": dates_test, "account_value": min_vals})
    stats_mpt = backtest_stats(min_df, value_col_name="account_value")
    return {"df": min_df, "stats": stats_mpt}


mpt_benchmark = compute_mpt_benchmark(test, env_kwargs)

# %% [markdown]
# ---
#
# ### Equal-Weighted Portfolio Benchmark
#
# - Calculate the performance of an **equal-weighted portfolio** benchmark.
# - This benchmark assumes that all assets in the portfolio are equally weighted, and their daily returns are averaged to compute the portfolio's overall return.
#
# ##### Workflow:
#
# 1. **Daily Returns Calculation**:
#
#    - Group the test dataset by `date`.
#    - Compute the percentage change (`pct_change`) in the `close` prices for each group.
#    - Calculate the mean of the daily percentage changes to represent the portfolio's daily return.
#
# 2. **Cumulative Portfolio Value**:
#
#    - Reset the index of the daily returns to create a DataFrame (`ew_df`).
#    - Compute the cumulative product of the daily returns (`cumprod`) to calculate the portfolio's cumulative value over time.
#    - Multiply the cumulative returns by the initial portfolio value (`initial_amount`) to get the portfolio's account value.
#
# 3. **Performance Metrics**:
#    - Use the `backtest_stats` function to calculate performance metrics for the equal-weighted portfolio, such as annual return, cumulative return, and volatility.

# %%
def compute_equal_weighted_benchmark(df, initial_amount=100_000):
    # Pivot to have one column per ticker
    price_wide = df.pivot_table(
        index="date", columns="tic", values="close"
    ).sort_index()

    # Compute each ticker's daily return, then average equally
    daily_rets = price_wide.pct_change().fillna(0).mean(axis=1)

    # Build the equity curve
    ew_df = pd.DataFrame({"date": daily_rets.index, "daily_return": daily_rets.values})
    ew_df["account_value"] = (ew_df["daily_return"] + 1).cumprod() * initial_amount

    # Compute performance statistics
    stats_ew = backtest_stats(ew_df, value_col_name="account_value")

    return {"df": ew_df.reset_index(drop=True), "stats": stats_ew}


ew_benchmark = compute_equal_weighted_benchmark(test, env_kwargs["initial_amount"])

# %% [markdown]
# ---
#
# ### SPY Benchmark
#
# - **Objective**: Calculate the benchmark performance of the `SPY ETF`, which tracks the **S&P 500** index.
# - **Purpose**: This function provides a baseline for comparing the performance of reinforcement learning models and other portfolio strategies.
#
# ##### Workflow:
#
# 1. **Data Retrieval**:
#    - Use the `get_baseline` function to fetch the historical closing prices of the SPY ETF for the test period.
# 2. **Daily Returns Calculation**:
#    - Compute the percentage change (`pct_change`) in the SPY closing prices to calculate daily returns.
# 3. **Cumulative Portfolio Value**:
#    - Create a DataFrame (`spy_df`) with the daily returns and calculate the cumulative product (`cumprod`) of the daily returns to compute the portfolio's cumulative value over time.
#    - Multiply the cumulative returns by the initial portfolio value (`initial_amount`) to get the portfolio's account value.
# 4. **Performance Metrics**:
#    - Use the `backtest_stats` function to calculate performance metrics for the SPY benchmark, such as annual return, cumulative return, and volatility.

# %%
def compute_spy_benchmark(test, env_kwargs):
    spy_close = get_baseline("SPY", test_start_date, end_date)["close"]
    spy_ret = spy_close.pct_change().dropna()
    spy_df = pd.DataFrame({"date": spy_ret.index, "daily_return": spy_ret.values})
    spy_df["account_value"] = (spy_df.daily_return + 1).cumprod() * env_kwargs[
        "initial_amount"
    ]
    stats_spy = backtest_stats(spy_df, value_col_name="account_value")
    return {"df": spy_df, "stats": stats_spy}


spy_benchmark = compute_spy_benchmark(test, env_kwargs)

# %%
benchmarks = {
    "MPT": mpt_benchmark,
    "EW": ew_benchmark,
    "SPY": spy_benchmark,
}

results.update(benchmarks)

# %% [markdown]
# ## Performance Summary

# %%
perf_stats = pd.DataFrame({key.upper(): res["stats"] for key, res in results.items()})
display(perf_stats)

# %%
comparison_metrics = [
    "Cumulative returns",
    "Annual return",
    "Annual volatility",
    "Sharpe ratio",
    "Max drawdown",
]

# Filter the performance statistics for the selected metrics
comparison_table = perf_stats.loc[comparison_metrics]


# Plot the comparison metrics as a bar chart
comparison_table.T.plot(kind="bar", figsize=(16, 8))
plt.title("Comparison of Key Metrics Across Models")
plt.ylabel("Metric Value")
plt.xlabel("Models")
plt.xticks(rotation=45)
plt.legend(title="Metrics", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# Visualize the cumulative returns of various strategies over time

# %%
def plot_cumulative_returns(results):
    plt.figure(figsize=(12, 8))
    for name, res in results.items():
        # Ensure the date column is converted to datetime
        res["df"]["date"] = pd.to_datetime(res["df"]["date"])
        # Filter data to start from the trade start date
        filtered_df = res["df"][res["df"]["date"] >= test_start_date]
        cum = (
            (filtered_df["daily_return"] + 1).cumprod() - 1
            if "daily_return" in filtered_df
            else filtered_df["account_value"] / filtered_df["account_value"].iloc[0] - 1
        )
        plt.plot(filtered_df["date"], cum, label=name)
    plt.title("Cumulative Returns")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.legend()
    plt.show()


plot_cumulative_returns(results)
